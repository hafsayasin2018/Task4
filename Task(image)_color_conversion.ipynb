# %%
import cv2
import numpy as np
from PIL import Image

# %% [markdown]
# ## Generic code:

# %%
im_path = "/content/download1.png"


im_array = cv2.imread(im_path)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))

#In BGR format, define the range of red color 
def_min_range = (0, 0, 100)
def_max_range = (100, 100, 255)
# To get a binary mask of red_color pixels set the threshold of image
red_mask = cv2.inRange(im_array, def_min_range, def_max_range)
# Replace all red pixels with black pixels
im_array[red_mask != 0] = (0, 0, 0)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=222x227 at 0x7EFD3BA32C70>
# <PIL.Image.Image image mode=RGB size=222x227 at 0x7EFD3BA32970>

# %%
im_path = "/content/images.jpeg"


im_array = cv2.imread(im_path)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))

#In BGR format, define the range of red color 
def_min_range = (0, 0, 100)
def_max_range = (100, 100, 255)
# To get a binary mask of red_color pixels set the threshold of image
red_mask = cv2.inRange(im_array, def_min_range, def_max_range)
# Replace all red pixels with black pixels
im_array[red_mask != 0] = (0, 0, 0)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=297x169 at 0x7EFD3CE47E80>
# <PIL.Image.Image image mode=RGB size=297x169 at 0x7EFD3CCC4B50>

# %%
im_path = "/content/baboon.png"


im_array = cv2.imread(im_path)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))

#In BGR format, define the range of red color 
def_min_range = (0, 0, 100)
def_max_range = (100, 100, 255)
# To get a binary mask of red_color pixels set the threshold of image
red_mask = cv2.inRange(im_array, def_min_range, def_max_range)
# Replace all red pixels with black pixels
im_array[red_mask != 0] = (0, 0, 0)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFD3CCD7FA0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFD3CCD7CD0>

# %%
im_path = "/content/image.png"


im_array = cv2.imread(im_path)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))

#In BGR format, define the range of red color 
def_min_range = (0, 0, 100)
def_max_range = (100, 100, 255)
# To get a binary mask of red_color pixels set the threshold of image
red_mask = cv2.inRange(im_array, def_min_range, def_max_range)
# Replace all red pixels with black pixels
im_array[red_mask != 0] = (0, 0, 0)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=296x280 at 0x7EFD3C488040>
# <PIL.Image.Image image mode=RGB size=296x280 at 0x7EFD3B9CEF40>

# %%
im_path = "/content/image (1).png"

# This image take less range to meet the orange values


im_array = cv2.imread(im_path)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))

#In BGR format, define the range of red color 
def_min_range = (0, 0, 100)
def_max_range = (50, 50, 255)
# To get a binary mask of red_color pixels set the threshold of image
red_mask = cv2.inRange(im_array, def_min_range, def_max_range)
# Replace all red pixels with black pixels
im_array[red_mask != 0] = (0, 0, 0)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=960x960 at 0x7EFD3C488100>
# <PIL.Image.Image image mode=RGB size=960x960 at 0x7EFD3B9CECA0>
